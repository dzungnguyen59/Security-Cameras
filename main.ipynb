# %%
from modules.core import TrackingSystem

if __name__ == "__main__":

    app = TrackingSystem(config_path="config.json")
    
    # Chạy hệ thống
    app.run()
# Out:
# Đang khởi tạo hệ thống...
# --- LUỒNG GNN WORKER ĐÃ KHỞI CHẠY ---
# WARNING  | Max age > max observations, increasing size of max observations...
# SUCCESS  | BoostTrack: det_thresh=0.6, max_age=60, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=None, asso_func=iou, use_ecc=True, min_box_area=10, aspect_ratio_thresh=1.6, cmc_method=ecc, lambda_iou=0.5, lambda_mhd=0.25, lambda_shape=0.25, use_dlo_boost=True, use_duo_boost=True, dlo_boost_coef=0.65, s_sim_corr=False, use_rich_s=True, use_sb=True, use_vt=True, with_reid=True, reid=None
# INFO     | BoxMOT v16.0.8 🚀 Python-3.12.3 torch-2.9.1+cu128
# CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# INFO     | weights/osnet_x0_25_msmt17.pt
# INFO     | [PID 44354] Found existing ReID weights at weights/osnet_x0_25_msmt17.pt; skipping download.
# SUCCESS  | Loaded pretrained weights from weights/osnet_x0_25_msmt17.pt
# [cam1] Đã khởi chạy luồng đọc dữ liệu.
# [cam1] Đang cố gắng kết nối tới mạng...
# WARNING  | Max age > max observations, increasing size of max observations...
# SUCCESS  | BoostTrack: det_thresh=0.6, max_age=60, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=None, asso_func=iou, use_ecc=True, min_box_area=10, aspect_ratio_thresh=1.6, cmc_method=ecc, lambda_iou=0.5, lambda_mhd=0.25, lambda_shape=0.25, use_dlo_boost=True, use_duo_boost=True, dlo_boost_coef=0.65, s_sim_corr=False, use_rich_s=True, use_sb=True, use_vt=True, with_reid=True, reid=None
# INFO     | BoxMOT v16.0.8 🚀 Python-3.12.3 torch-2.9.1+cu128
# CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# INFO     | weights/osnet_x0_25_msmt17.pt
# INFO     | [PID 44354] Found existing ReID weights at weights/osnet_x0_25_msmt17.pt; skipping download.
# [cam1] Kết nối THÀNH CÔNG!
# SUCCESS  | Loaded pretrained weights from weights/osnet_x0_25_msmt17.pt
# [cam2] Đã khởi chạy luồng đọc dữ liệu.
# Đã mở 2 camera. Vui lòng đợi...
# [cam2] Đang cố gắng kết nối tới mạng...
# [cam2] Kết nối THÀNH CÔNG!
# DEBUG: Tạo ID mới cho Local 102 -> Global 1
# DEBUG: Tạo ID mới cho Local 103 -> Global 2
# [GNN Worker] Đã phát hiện phân mảnh. Gộp ID 2 vào ID 1 (Độ giống: 0.80)
# DEBUG: Tạo ID mới cho Local 105 -> Global 3
# [mjpeg @ 0x75b470010ac0] overread 8
# [GNN Worker] Đã phát hiện phân mảnh. Gộp ID 3 vào ID 1 (Độ giống: 0.82)
# DEBUG: Tạo ID mới cho Local 106 -> Global 4
# DEBUG: Tạo ID mới cho Local 107 -> Global 5
# [mjpeg @ 0x75b470010ac0] overread 8
# [mjpeg @ 0x75b470010ac0] overread 8
# DEBUG: Tạo ID mới cho Local 112 -> Global 6
# [GNN Worker] Đã phát hiện phân mảnh. Gộp ID 6 vào ID 1 (Độ giống: 0.84)
# DEBUG: Tạo ID mới cho Local 116 -> Global 7
# DEBUG: Tạo ID mới cho Local 117 -> Global 8
# DEBUG: Tạo ID mới cho Local 123 -> Global 9
# [mjpeg @ 0x75b470010ac0] overread 8
# DEBUG: Tạo ID mới cho Local 124 -> Global 10
# DEBUG: Tạo ID mới cho Local 115 -> Global 11
# Camera cam1 đã được giải phóng.
# Camera cam2 đã được giải phóng.
